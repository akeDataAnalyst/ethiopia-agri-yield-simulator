# %%
import streamlit as st
import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt

# ────────────────────────────────────────────────
# Load model and data
# ────────────────────────────────────────────────
model = joblib.load('yield_model.pkl')
df = pd.read_csv('ethiopia_agri_data.csv')

# Precompute some EDA aggregates for tabs
yearly_yield = df.groupby('Year')['Yield_ton_ha'].mean().reset_index()
region_yield = df.groupby('Region')['Yield_ton_ha'].mean().sort_values(ascending=False).reset_index()

# ────────────────────────────────────────────────
# Page config
# ────────────────────────────────────────────────
st.set_page_config(page_title="Ethiopia Agri Yield Simulator & Insights", layout="wide")
st.title("Ethiopia Agricultural Yield Simulator & Insights")
st.markdown("Interactive dashboard for exploring productivity interventions in Ethiopia. Portfolio project by Aklilu Abera for Dalberg Advisors Analyst role.")

# ────────────────────────────────────────────────
# Tabs
# ────────────────────────────────────────────────
tab_sim, tab_eda, tab_model = st.tabs(["🔧 Yield Simulator", "📊 EDA Insights (Phase 2)", "📈 Model & Insights (Phase 3)"])

# ────────────────────────────────────────────────
# Sidebar – shared inputs
# ────────────────────────────────────────────────
with st.sidebar:
    st.header("Simulation Controls")

    region = st.selectbox("Focus Region", 
                          ["Afar (Baseline)", "Tigray", "Amhara", "Oromia", 
                           "Central Ethiopia", "Sidama", "South Ethiopia", "South West Ethiopia"])

    crop = st.selectbox("Crop (for context)", 
                        ["Maize", "Sorghum", "Wheat", "Barley", "Teff"])

    rainfall = st.slider("Effective Rainfall (mm/year)", 200, 2400, 500, 50)
    fertilizer = st.slider("Fertilizer Use (kg/ha)", 20, 200, 60, 10)
    market_access = st.slider("Market Access Index (0–1)", 0.3, 1.0, 0.50, 0.05)

    st.subheader("Economic Assumptions")
    farm_size_ha = st.number_input("Avg Farm Size (ha)", value=1.5, step=0.1)
    households = st.number_input("Households Targeted", value=50000, step=1000, format="%d")
    price_per_ton = st.number_input("Price per Ton (USD)", value=400, step=50)
    cost_per_ha = st.number_input("Intervention Cost per ha (USD)", value=150, step=10)

# ────────────────────────────────────────────────
# Prediction logic (used in simulator tab)
# ────────────────────────────────────────────────
input_data = np.array([[rainfall, fertilizer, market_access]])
predicted_yield = model.predict(input_data)[0].round(2)

baseline_input = np.array([[500, 60, 0.50]])
baseline_yield = model.predict(baseline_input)[0].round(2)

uplift_pct = ((predicted_yield - baseline_yield) / baseline_yield * 100).round(1) if baseline_yield > 0 else 0

# Economic calculations – use built-in round() on floats
extra_yield_ha   = predicted_yield - baseline_yield
extra_production = round(extra_yield_ha * farm_size_ha * households, 0)
extra_value      = round(extra_production * price_per_ton, 0)
total_cost       = round(cost_per_ha * farm_size_ha * households, 0)
roi = round(((extra_value - total_cost) / total_cost * 100), 0) if total_cost > 0 else 0

# ────────────────────────────────────────────────
# TAB 1: Yield Simulator
# ────────────────────────────────────────────────
with tab_sim:
    st.subheader(f"Simulator – {region} | {crop}")

    col1, col2, col3 = st.columns(3)
    col1.metric("Predicted Yield (t/ha)", f"{predicted_yield}")
    col2.metric("Baseline Yield (Afar-like)", f"{baseline_yield}")
    col3.metric("Yield Uplift", f"{uplift_pct}%", delta_color="normal")

    st.subheader("Estimated Scaled Impact")
    colA, colB, colC = st.columns(3)
    colA.metric("Extra Production (tons)", f"{extra_production:,}")
    colB.metric("Added Value (USD)", f"${extra_value:,}")
    colC.metric("ROI", f"{roi}%")

    st.markdown("**Your Inputs vs Baseline**")
    scenario_df = pd.DataFrame({
        "Parameter": ["Rainfall (mm)", "Fertilizer (kg/ha)", "Market Access", "Predicted Yield (t/ha)", "Uplift (%)"],
        "Value": [rainfall, fertilizer, market_access, predicted_yield, uplift_pct],
        "Baseline": [500, 60, 0.50, baseline_yield, 0.0]
    })
    st.dataframe(scenario_df, hide_index=True, use_container_width=True)

    # Yield comparison bar
    chart_data = pd.DataFrame({"Yield": [baseline_yield, predicted_yield]}, index=["Baseline", "Scenario"])
    st.bar_chart(chart_data, color=["#d3d3d3", "#4CAF50"])

# ────────────────────────────────────────────────
# TAB 2: EDA Insights (Phase 2 Recap)
# ────────────────────────────────────────────────
with tab_eda:
    st.subheader("National Yield Trend (2000–2023)")
    st.line_chart(yearly_yield.set_index('Year')['Yield_ton_ha'], use_container_width=True)

    st.subheader("Average Yield by Region (t/ha)")
    st.bar_chart(region_yield.set_index('Region')['Yield_ton_ha'].sort_values(ascending=True), 
                 color="#2196F3", use_container_width=True)

    st.subheader("Key Phase 2 Highlights")
    st.markdown("""
    - National avg yield: ~2.95 t/ha  
    - Highest: South West Ethiopia (3.50), South Ethiopia (3.49)  
    - Lowest: Afar (1.57), Tigray (2.15)  
    - Strongest driver: Rainfall (corr 0.77)  
    - No clear time trend → stagnation without intervention
    """)

# ────────────────────────────────────────────────
# TAB 3: Model & Insights (Phase 3 Recap)
# ────────────────────────────────────────────────
with tab_model:
    st.subheader("Model Performance & Coefficients")
    st.markdown("""
    **R²**: 0.7137 (explains ~71% of yield variation)  
    **RMSE**: 0.3924 t/ha  

    **Coefficients**:
    - Rainfall_mm: 0.000856  
    - Fertilizer_Use_kg_ha: 0.003023  
    - Market_Access_Index: 1.429643  
    - Intercept: 0.5803
    """)

    st.subheader("Full Package Scenario Recap")
    st.markdown("""
    - Baseline yield: ~1.90 t/ha  
    - Full intervention: ~2.93 t/ha  
    - Uplift: **+54.2%**  
    - Scaled (50k households): **$30.9M** added value, **175% ROI**
    """)

    st.info("Recommendation: Focus integrated packages (irrigation + inputs + market linkages) on vulnerable regions for maximum inclusive impact.")

# Footer
st.markdown("---")
st.caption("Portfolio Project | Aklilu Abera")
# Out:
# 2026-01-14 17:15:03.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.113 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.227 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.235 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# C:\Users\Eldu\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\Eldu\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 2026-01-14 17:15:03.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.307 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.309 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.311 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.318 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.326 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.336 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.344 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.351 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.360 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.366 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.368 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.384 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.388 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-14 17:15:03.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# StreamlitColorLengthError                 Traceback (most recent call last)
# Cell In[3], line 97
#      95     # Yield comparison bar
#      96     chart_data = pd.DataFrame({"Yield": [baseline_yield, predicted_yield]}, index=["Baseline", "Scenario"])
# ---> 97     st.bar_chart(chart_data, color=["#d3d3d3", "#4CAF50"])
#      99 # ────────────────────────────────────────────────
#     100 # TAB 2: EDA Insights (Phase 2 Recap)
#     101 # ────────────────────────────────────────────────
#     102 with tab_eda:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\streamlit\runtime\metrics_util.py:410, in gather_metrics.<locals>.wrapped_func(*args, **kwargs)
#     408         _LOGGER.debug("Failed to collect command telemetry", exc_info=ex)
#     409 try:
# --> 410     result = non_optional_func(*args, **kwargs)
#     411 except RerunException as ex:
#     412     # Duplicated from below, because static analysis tools get confused
#     413     # by deferring the rethrow.
#     414     if tracking_activated and command_telemetry:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\streamlit\elements\vega_charts.py:1225, in VegaChartsMixin.bar_chart(self, data, x, y, x_label, y_label, color, horizontal, stack, width, height, use_container_width)
#    1217     raise StreamlitAPIException(
#    1218         "Streamlit does not support non-stacked (grouped) bar charts with Altair 4.x. Please upgrade to Version 5."
#    1219     )
#    1221 bar_chart_type = (
#    1222     ChartType.HORIZONTAL_BAR if horizontal else ChartType.VERTICAL_BAR
#    1223 )
# -> 1225 chart, add_rows_metadata = generate_chart(
#    1226     chart_type=bar_chart_type,
#    1227     data=data,
#    1228     x_from_user=x,
#    1229     y_from_user=y,
#    1230     x_axis_label=x_label,
#    1231     y_axis_label=y_label,
#    1232     color_from_user=color,
#    1233     size_from_user=None,
#    1234     width=width,
#    1235     height=height,
#    1236     stack=stack,
#    1237 )
#    1238 return cast(
#    1239     "DeltaGenerator",
#    1240     self._altair_chart(
#    (...)
#    1245     ),
#    1246 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\streamlit\elements\lib\built_in_chart_utils.py:230, in generate_chart(***failed resolving arguments***)
#     227     chart = chart.encode(opacity=opacity_enc)
#     229 # Set up color encoding.
# --> 230 color_enc = _get_color_encoding(
#     231     df, color_value, color_column, y_column_list, color_from_user
#     232 )
#     233 if color_enc is not None:
#     234     chart = chart.encode(color=color_enc)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\streamlit\elements\lib\built_in_chart_utils.py:918, in _get_color_encoding(df, color_value, color_column, y_column_list, color_from_user)
#     915 color_values = cast(Collection[Color], color_value)
#     917 if len(color_values) != len(y_column_list):
# --> 918     raise StreamlitColorLengthError(color_values, y_column_list)
#     920 if len(color_values) == 1:
#     921     return alt.ColorValue(to_css_color(cast(Any, color_value[0])))
#
# StreamlitColorLengthError: The list of colors `['#d3d3d3', '#4CAF50']` must have the same length as the list of columns to be colored `['Yield']`.
